# %%
from google.colab import drive
drive.mount('/content/gdrive/')

import pandas as pd

data = pd.read_csv('/content/gdrive/MyDrive/20220321.csv', encoding='cp949')
print(data)
# Out:
# Mounted at /content/gdrive/
#                      시설                                        주소  규모(제곱미터)  \
# 0           안양1동 주민센터지하                       안양시 만안구 장내로170(안양동)       570
# 1              안양중앙지하상가                       안양시 만안구 안양로301(안양동)      2310
# 2              안양역전지하상가                       안양시 만안구 만안로231(안양동)     15794
# 3          만안초등학교 앞 지하도                   안양시 만안구 안양로384번길13(안양동)       330
# 4              안양2동주민센터                   안양시 만안구 안양로384번길50(안양동)       327
# ..                  ...                                       ...       ...
# 202  비산1동화성파크드림아파트지하주차장                경기도 안양시 동안구 경수대로 947 (비산동)      2429
# 203    동편마을4단지아파트 지하주차장            경기도 안양시 동안구 동편로 135 (관양동 동편마을)     36927
# 204          동편마을 공영주차장            경기도 안양시 동안구 동편로39번길 20-5 (관양동)      5289
# 205      농수산물도매시장 지하주차장        경기도 안양시 동안구 흥안대로 313 (안양시농수산물도매시장)     13760
# 206    평촌더샵 센트럴시티 지하주차장  경기도 안양시 동안구 시민대로327번길 55 (관양동 평촌더샵센트럴시티)     59904
#
#      최대 수용인원(명)
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data['규모(제곱미터)'][10])
# Out:
# 274

# %%
import numpy as np
print(np.mean(data['규모(제곱미터)']))
print(np.std(data['규모(제곱미터)']))
# Out:
# 8397.985507246376
# 15776.5824251995
